# %% [markdown]
# 1. 3 tables: (b), (anotp), (ap)
# 2. split into train,test, evaluate on test, report statistics. do for 30 splits
# 3.

# %% [markdown]
#                         DATASET (b)
#                 precision               recall
#                 min, max, avg, stddev   min, max, avg, stddev
# predictor sets
# full dataset
# INVBOOL
# INVOCNT
