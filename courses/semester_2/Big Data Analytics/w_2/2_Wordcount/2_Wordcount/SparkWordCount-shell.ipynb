# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

# %%
def main():
    # input path
    input_file = "./wiki_00"

    # output directory
    output_directory = "./output_dir"  #  output directory

    spark_conf = SparkConf().setAppName("SparkWordCount")
    spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()

    try:
        # read input
        text_file = spark.sparkContext.textFile(input_file)

        # word count
        counts = text_file.flatMap(lambda line: line.split(" ")) \
                          .map(lambda word: (word, 1)) \
                          .reduceByKey(lambda a, b: a + b)

        # Save the counts
        counts.saveAsTextFile(output_directory)

    finally:
        spark.stop()

if __name__ == "__main__":
    main()
# Out:
# 24/03/14 15:41:21 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/14 15:41:21 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/03/14 15:41:21 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
