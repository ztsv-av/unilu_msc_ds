# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, split

# spark session
spark = SparkSession.builder.appName("SparkWordCount").getOrCreate()
# Out:
# 24/03/14 15:46:29 WARN Utils: Your hostname, MF0023 resolves to a loopback address: 127.0.0.1; using 10.164.40.27 instead (on interface en1)
# 24/03/14 15:46:29 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/14 15:46:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/03/14 15:46:30 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/03/14 15:46:30 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/03/14 15:46:30 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.

# %%
text_file = spark.read.text("./AA")

word_counts = (
    text_file
    .select(explode(split("value", " ")).alias("word"))
    .groupBy("word")
    .count()
)

word_counts.show()
# Out:
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |      those| 3719|
# |         By| 2307|
# |  "Regiment|    1|
# |       some| 9981|
# |      still| 3153|
# |        few| 2420|
# |       July| 1522|
# |     harder|   94|
# |        C-9|    1|
# |      Zhou,|    5|
# |     seeds,|   26|
# | Dynasties.|    5|
# |     brands|   59|
# |        art| 1078|
# |      Muse"|    2|
# |      cures|    8|
# |      Bird"|    5|
# |influences.|   65|
# | Konsthall,|    1|
# |       (New|   37|
# +-----------+-----+
# only showing top 20 rows
