# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, split

# spark session
spark = SparkSession.builder.appName("SparkWordCount").getOrCreate()

# %%
text_file = spark.read.text("../Data/enwiki-articles/AA")

word_counts = (
    text_file
    .select(explode(split("value", " ")).alias("word"))
    .groupBy("word")
    .count()
)

word_counts.show()
# Out:
# [Stage 3:======================>                                    (3 + 5) / 8]
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |      those| 3719|
# |         By| 2307|
# |  "Regiment|    1|
# |       some| 9981|
# |      still| 3153|
# |        few| 2420|
# |       July| 1522|
# |     harder|   94|
# |        C-9|    1|
# |      Zhou,|    5|
# |     seeds,|   26|
# | Dynasties.|    5|
# |     brands|   59|
# |        art| 1078|
# |      Muse"|    2|
# |      cures|    8|
# |      Bird"|    5|
# |influences.|   65|
# | Konsthall,|    1|
# |       (New|   37|
# +-----------+-----+
# only showing top 20 rows
