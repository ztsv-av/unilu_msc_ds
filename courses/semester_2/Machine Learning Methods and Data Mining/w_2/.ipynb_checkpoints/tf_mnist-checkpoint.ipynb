# %%
# Import TensorFlow and other libraries
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Download and explore the dataset
from sklearn import datasets

digits = datasets.load_digits()

# Information about the dataset
npoints, xres, yres = digits.images.shape
print('The number of data points in the dataset is {:d}'.format(npoints))
print('The image resolution is {:d}x{:d}'.format(xres, yres))

# Visualise 
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % label)
# Out:
# The number of data points in the dataset is 1797
# The image resolution is 8x8

# %%
# Create a dataset
from sklearn.model_selection import train_test_split

batch_size = 16
img_height = xres
img_width = yres
class_names = list(range(10))

# Split data into 50% train and 50% test subsets
X_train, X_test, y_train, y_test = train_test_split(digits.images, digits.target, test_size=0.5, shuffle=False)

X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(batch_size)
val_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(batch_size)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"), cmap=plt.cm.gray_r, interpolation="nearest")
    plt.title(labels[i].numpy())
    plt.axis("off")

# %%
# Create the mode
num_classes = len(class_names)

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Checkpoint
checkpoint_filepath = '/tmp/checkpoint_1'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1)

# %%
# Train the model
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[model_checkpoint_callback]
)
# Out:
# Epoch 1/50
# 35/57 [=================>............] - ETA: 0s - loss: 2.1038 - accuracy: 0.2661
# Epoch 00001: val_accuracy improved from -inf to 0.78087, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 1s 4ms/step - loss: 1.8617 - accuracy: 0.3998 - val_loss: 0.9949 - val_accuracy: 0.7809
# Epoch 2/50
# 36/57 [=================>............] - ETA: 0s - loss: 0.7619 - accuracy: 0.7865
# Epoch 00002: val_accuracy improved from 0.78087 to 0.83982, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.8096 - val_loss: 0.5391 - val_accuracy: 0.8398
# Epoch 3/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.4225 - accuracy: 0.8696
# Epoch 00003: val_accuracy improved from 0.83982 to 0.89210, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 3ms/step - loss: 0.3667 - accuracy: 0.8920 - val_loss: 0.3634 - val_accuracy: 0.8921
# Epoch 4/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.2216 - accuracy: 0.9338
# Epoch 00004: val_accuracy improved from 0.89210 to 0.92881, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2027 - accuracy: 0.9376 - val_loss: 0.2594 - val_accuracy: 0.9288
# Epoch 5/50
# 33/57 [================>.............] - ETA: 0s - loss: 0.1349 - accuracy: 0.9508
# Epoch 00005: val_accuracy did not improve from 0.92881
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1429 - accuracy: 0.9555 - val_loss: 0.2587 - val_accuracy: 0.9232
# Epoch 6/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.1218 - accuracy: 0.9607
# Epoch 00006: val_accuracy did not improve from 0.92881
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9655 - val_loss: 0.2734 - val_accuracy: 0.9277
# Epoch 7/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.0918 - accuracy: 0.9706
# Epoch 00007: val_accuracy improved from 0.92881 to 0.93660, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0838 - accuracy: 0.9744 - val_loss: 0.2109 - val_accuracy: 0.9366
# Epoch 8/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0685 - accuracy: 0.9768
# Epoch 00008: val_accuracy improved from 0.93660 to 0.95217, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 0.9833 - val_loss: 0.1536 - val_accuracy: 0.9522
# Epoch 9/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.0599 - accuracy: 0.9798
# Epoch 00009: val_accuracy did not improve from 0.95217
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0533 - accuracy: 0.9833 - val_loss: 0.2140 - val_accuracy: 0.9299
# Epoch 10/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0400 - accuracy: 0.9902
# Epoch 00010: val_accuracy did not improve from 0.95217
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 0.9866 - val_loss: 0.2131 - val_accuracy: 0.9288
# Epoch 11/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.0336 - accuracy: 0.9908
# Epoch 00011: val_accuracy did not improve from 0.95217
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9878 - val_loss: 0.1969 - val_accuracy: 0.9422
# Epoch 12/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0292 - accuracy: 0.9911
# Epoch 00012: val_accuracy did not improve from 0.95217
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 0.1745 - val_accuracy: 0.9511
# Epoch 13/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0329 - accuracy: 0.9911
# Epoch 00013: val_accuracy did not improve from 0.95217
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9911 - val_loss: 0.1645 - val_accuracy: 0.9511
# Epoch 14/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0304 - accuracy: 0.9929
# Epoch 00014: val_accuracy did not improve from 0.95217
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9889 - val_loss: 0.1953 - val_accuracy: 0.9488
# Epoch 15/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0320 - accuracy: 0.9875
# Epoch 00015: val_accuracy improved from 0.95217 to 0.95439, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9911 - val_loss: 0.1617 - val_accuracy: 0.9544
# Epoch 16/50
# 30/57 [==============>...............] - ETA: 0s - loss: 0.0245 - accuracy: 0.9937
# Epoch 00016: val_accuracy improved from 0.95439 to 0.96552, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9944 - val_loss: 0.1457 - val_accuracy: 0.9655
# Epoch 17/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0177 - accuracy: 0.9980
# Epoch 00017: val_accuracy improved from 0.96552 to 0.97108, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9978 - val_loss: 0.1316 - val_accuracy: 0.9711
# Epoch 18/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0099 - accuracy: 0.9980
# Epoch 00018: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9989 - val_loss: 0.1594 - val_accuracy: 0.9633
# Epoch 19/50
# 33/57 [================>.............] - ETA: 0s - loss: 0.0157 - accuracy: 0.9905
# Epoch 00019: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.9933 - val_loss: 0.1661 - val_accuracy: 0.9655
# Epoch 20/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0074 - accuracy: 0.9980
# Epoch 00020: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.1614 - val_accuracy: 0.9622
# Epoch 21/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0194 - accuracy: 0.9863
# Epoch 00021: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9900 - val_loss: 0.1602 - val_accuracy: 0.9600
# Epoch 22/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00022: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9677
# Epoch 23/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0056 - accuracy: 0.9980
# Epoch 00023: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9911 - val_loss: 0.3185 - val_accuracy: 0.9143
# Epoch 24/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.2639 - accuracy: 0.9214
# Epoch 00024: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1894 - accuracy: 0.9399 - val_loss: 0.1952 - val_accuracy: 0.9499
# Epoch 25/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0506 - accuracy: 0.9819
# Epoch 00025: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9866 - val_loss: 0.1635 - val_accuracy: 0.9555
# Epoch 26/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0109 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.1804 - val_accuracy: 0.9566
# Epoch 27/50
# 33/57 [================>.............] - ETA: 0s - loss: 0.0175 - accuracy: 0.9962
# Epoch 00027: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9967 - val_loss: 0.1589 - val_accuracy: 0.9655
# Epoch 28/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9666
# Epoch 29/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0085 - accuracy: 0.9982
# Epoch 00029: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.1894 - val_accuracy: 0.9577
# Epoch 30/50
# 33/57 [================>.............] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9633
# Epoch 31/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0052 - accuracy: 0.9980
# Epoch 00031: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.2570 - val_accuracy: 0.9488
# Epoch 32/50
# 33/57 [================>.............] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.1419 - val_accuracy: 0.9711
# Epoch 33/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0105 - accuracy: 0.9940
# Epoch 00033: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9967 - val_loss: 0.1426 - val_accuracy: 0.9655
# Epoch 34/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0115 - accuracy: 0.9980
# Epoch 00034: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.1568 - val_accuracy: 0.9700
# Epoch 35/50
# 31/57 [===============>..............] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9689
# Epoch 36/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0092 - accuracy: 0.9929
# Epoch 00036: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9955 - val_loss: 0.1589 - val_accuracy: 0.9622
# Epoch 37/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.0196 - accuracy: 0.9945
# Epoch 00037: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.1678 - val_accuracy: 0.9622
# Epoch 38/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1834 - val_accuracy: 0.9600
# Epoch 39/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9644
# Epoch 40/50
# 32/57 [===============>..............] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.97108
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9711
# Epoch 41/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00041: val_accuracy improved from 0.97108 to 0.97442, saving model to /tmp/checkpoint_1
# 57/57 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9744
# Epoch 42/50
# 35/57 [=================>............] - ETA: 0s - loss: 3.9011e-04 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 7.4873e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9677
# Epoch 43/50
# 36/57 [=================>............] - ETA: 0s - loss: 8.3726e-04 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 8.2936e-04 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9700
# Epoch 44/50
# 36/57 [=================>............] - ETA: 0s - loss: 4.8674e-04 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 4.5265e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9733
# Epoch 45/50
# 31/57 [===============>..............] - ETA: 0s - loss: 2.8425e-04 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 4.9509e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9722
# Epoch 46/50
# 34/57 [================>.............] - ETA: 0s - loss: 4.1884e-04 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 4.2126e-04 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9689
# Epoch 47/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9644
# Epoch 48/50
# 35/57 [=================>............] - ETA: 0s - loss: 0.0262 - accuracy: 0.9946
# Epoch 00048: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9944 - val_loss: 0.2704 - val_accuracy: 0.9466
# Epoch 49/50
# 34/57 [================>.............] - ETA: 0s - loss: 0.0163 - accuracy: 0.9945
# Epoch 00049: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9944 - val_loss: 0.1540 - val_accuracy: 0.9689
# Epoch 50/50
# 36/57 [=================>............] - ETA: 0s - loss: 0.0063 - accuracy: 0.9983
# Epoch 00050: val_accuracy did not improve from 0.97442
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.1925 - val_accuracy: 0.9533

# %%
# Loading best model
model.load_weights(checkpoint_filepath)

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 8, 8, 16)          160
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 2, 64)          18496
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 1, 1, 64)          0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 32,906
# Trainable params: 32,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Visualize training results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Analyze the results
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = model.predict(X_test)
predicted = np.argmax(tf.nn.softmax(predictions), axis=-1)

print(
    f"Classification report:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

# Confusion matrix
cm = confusion_matrix(y_test, predicted, labels=class_names)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=class_names)
disp.plot()
plt.show()
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        88
#            1       0.98      0.98      0.98        91
#            2       1.00      1.00      1.00        86
#            3       0.99      0.97      0.98        91
#            4       0.98      0.93      0.96        92
#            5       0.93      0.98      0.95        91
#            6       0.98      0.99      0.98        91
#            7       0.99      0.99      0.99        89
#            8       0.99      0.95      0.97        88
#            9       0.93      0.97      0.95        92
#
#     accuracy                           0.97       899
#    macro avg       0.98      0.97      0.97       899
# weighted avg       0.98      0.97      0.97       899

# %% [markdown]
# Real MNIST dataset

# %%
# Import database
import idx2numpy

file_X_train = 'mnist/train-images.idx3-ubyte' 
file_y_train = 'mnist/train-labels.idx1-ubyte'
file_X_test = 'mnist/t10k-images.idx3-ubyte' 
file_y_test = 'mnist/t10k-labels.idx1-ubyte' 

X_train = idx2numpy.convert_from_file(file_X_train)
y_train = idx2numpy.convert_from_file(file_y_train)
X_test = idx2numpy.convert_from_file(file_X_test)
y_test = idx2numpy.convert_from_file(file_y_test)

# Information about the dataset
npoints_train, xres, yres = X_train.shape
npoints_test, _, _ = X_test.shape
print('The number of data points in the training dataset is {:d}'.format(npoints_train))
print('The number of data points in the test dataset is {:d}'.format(npoints_test))
print('The image resolution is {:d}x{:d}'.format(xres, yres))

# Split data into 20% and 80% subsets and ignore the 80% dataset
X_train, _, y_train, _ = train_test_split(
    X_train, y_train, test_size=0.8, shuffle=True)
npoints_train, _, _ = X_train.shape
print('The number of data points in the redced training dataset is {:d}'.format(npoints_train))

# Visualise 
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(10, 3))
for ax, image, label in zip(axes, X_train, y_train):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % label)


# Prepare datasets for TF
batch_size = 32
img_height = xres
img_width = yres
class_names = list(range(10))

X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

train_ds = tf.data.Dataset.from_tensor_slices((X_train.astype('float32'), y_train.astype('float32'))).batch(batch_size)
val_ds = tf.data.Dataset.from_tensor_slices((X_test.astype('float32'), y_test.astype('float32'))).batch(batch_size)
# Out:
# The number of data points in the training dataset is 60000
# The number of data points in the test dataset is 10000
# The image resolution is 28x28
# The number of data points in the redced training dataset is 12000

# %%
# Create the mode
num_classes = len(class_names)

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# Checkpoint
checkpoint_filepath = '/tmp/checkpoint_2'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1)

# EarlyStopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    patience=10,
    mode='auto', 
    baseline=None, 
    restore_best_weights=True
)


# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[model_checkpoint_callback, early_stopping]
)

# Loading best model
model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 370/375 [============================>.] - ETA: 0s - loss: 1.0378 - accuracy: 0.8018
# Epoch 00001: val_accuracy improved from -inf to 0.96040, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 4s 9ms/step - loss: 1.0267 - accuracy: 0.8037 - val_loss: 0.1294 - val_accuracy: 0.9604
# Epoch 2/100
# 372/375 [============================>.] - ETA: 0s - loss: 0.1636 - accuracy: 0.9489
# Epoch 00002: val_accuracy improved from 0.96040 to 0.96750, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1637 - accuracy: 0.9488 - val_loss: 0.1026 - val_accuracy: 0.9675
# Epoch 3/100
# 374/375 [============================>.] - ETA: 0s - loss: 0.1068 - accuracy: 0.9672
# Epoch 00003: val_accuracy did not improve from 0.96750
# 375/375 [==============================] - 5s 12ms/step - loss: 0.1069 - accuracy: 0.9672 - val_loss: 0.1136 - val_accuracy: 0.9656
# Epoch 4/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9738
# Epoch 00004: val_accuracy improved from 0.96750 to 0.97110, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0793 - accuracy: 0.9738 - val_loss: 0.0937 - val_accuracy: 0.9711
# Epoch 5/100
# 372/375 [============================>.] - ETA: 0s - loss: 0.0663 - accuracy: 0.9779
# Epoch 00005: val_accuracy improved from 0.97110 to 0.97310, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0673 - accuracy: 0.9778 - val_loss: 0.0951 - val_accuracy: 0.9731
# Epoch 6/100
# 372/375 [============================>.] - ETA: 0s - loss: 0.0643 - accuracy: 0.9792
# Epoch 00006: val_accuracy improved from 0.97310 to 0.98060, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0643 - accuracy: 0.9793 - val_loss: 0.0691 - val_accuracy: 0.9806
# Epoch 7/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0453 - accuracy: 0.9843
# Epoch 00007: val_accuracy did not improve from 0.98060
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0455 - accuracy: 0.9843 - val_loss: 0.0841 - val_accuracy: 0.9781
# Epoch 8/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9838
# Epoch 00008: val_accuracy did not improve from 0.98060
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0446 - accuracy: 0.9838 - val_loss: 0.1082 - val_accuracy: 0.9737
# Epoch 9/100
# 372/375 [============================>.] - ETA: 0s - loss: 0.0469 - accuracy: 0.9841
# Epoch 00009: val_accuracy improved from 0.98060 to 0.98240, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0467 - accuracy: 0.9842 - val_loss: 0.0721 - val_accuracy: 0.9824
# Epoch 10/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0474 - accuracy: 0.9845
# Epoch 00010: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0473 - accuracy: 0.9845 - val_loss: 0.0624 - val_accuracy: 0.9821
# Epoch 11/100
# 374/375 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9874
# Epoch 00011: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0376 - accuracy: 0.9874 - val_loss: 0.0722 - val_accuracy: 0.9808
# Epoch 12/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0363 - accuracy: 0.9874
# Epoch 00012: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0363 - accuracy: 0.9874 - val_loss: 0.0687 - val_accuracy: 0.9817
# Epoch 13/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9882
# Epoch 00013: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0373 - accuracy: 0.9882 - val_loss: 0.0781 - val_accuracy: 0.9810
# Epoch 14/100
# 374/375 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9886
# Epoch 00014: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0394 - accuracy: 0.9886 - val_loss: 0.0744 - val_accuracy: 0.9813
# Epoch 15/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9896
# Epoch 00015: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0337 - accuracy: 0.9897 - val_loss: 0.0875 - val_accuracy: 0.9792
# Epoch 16/100
# 374/375 [============================>.] - ETA: 0s - loss: 0.0283 - accuracy: 0.9907
# Epoch 00016: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 8s 22ms/step - loss: 0.0292 - accuracy: 0.9907 - val_loss: 0.0809 - val_accuracy: 0.9816
# Epoch 17/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0392 - accuracy: 0.9871
# Epoch 00017: val_accuracy did not improve from 0.98240
# 375/375 [==============================] - 9s 24ms/step - loss: 0.0390 - accuracy: 0.9872 - val_loss: 0.0918 - val_accuracy: 0.9777
# Epoch 18/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9904
# Epoch 00018: val_accuracy improved from 0.98240 to 0.98550, saving model to /tmp/checkpoint_2
# 375/375 [==============================] - 9s 24ms/step - loss: 0.0283 - accuracy: 0.9905 - val_loss: 0.0655 - val_accuracy: 0.9855
# Epoch 19/100
# 372/375 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.9924
# Epoch 00019: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 9s 24ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.0766 - val_accuracy: 0.9813
# Epoch 20/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9941
# Epoch 00020: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 10s 26ms/step - loss: 0.0196 - accuracy: 0.9941 - val_loss: 0.1195 - val_accuracy: 0.9754
# Epoch 21/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9906
# Epoch 00021: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 10s 26ms/step - loss: 0.0324 - accuracy: 0.9906 - val_loss: 0.0840 - val_accuracy: 0.9823
# Epoch 22/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9910
# Epoch 00022: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 9s 23ms/step - loss: 0.0290 - accuracy: 0.9910 - val_loss: 0.1163 - val_accuracy: 0.9734
# Epoch 23/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9917
# Epoch 00023: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0842 - val_accuracy: 0.9818
# Epoch 24/100
# 372/375 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9903
# Epoch 00024: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.0790 - val_accuracy: 0.9816
# Epoch 25/100
# 375/375 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9940
# Epoch 00025: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.0876 - val_accuracy: 0.9811
# Epoch 26/100
# 374/375 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 0.9926
# Epoch 00026: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.0893 - val_accuracy: 0.9824
# Epoch 27/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0281 - accuracy: 0.9918
# Epoch 00027: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0279 - accuracy: 0.9918 - val_loss: 0.1138 - val_accuracy: 0.9781
# Epoch 28/100
# 373/375 [============================>.] - ETA: 0s - loss: 0.0275 - accuracy: 0.9918
# Epoch 00028: val_accuracy did not improve from 0.98550
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.1062 - val_accuracy: 0.9764

# %%
# Visualize training results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bb/1b6mrl053f77r4xlds69srw1dc5ctl/T/ipykernel_12389/1868650013.py in <module>
#      10 plt.figure(figsize=(8, 8))
#      11 plt.subplot(1, 2, 1)
# ---> 12 plt.plot(epochs_range, acc, label='Training Accuracy')
#      13 plt.plot(epochs_range, val_acc, label='Validation Accuracy')
#      14 plt.legend(loc='lower right')
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499
#     500         if x.shape[0] != y.shape[0]:
# --> 501             raise ValueError(f"x and y must have same first dimension, but "
#     502                              f"have shapes {x.shape} and {y.shape}")
#     503         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (28,)

# %%
# Analyze the results
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Predicting
predictions = model.predict(X_test)
predicted = np.argmax(tf.nn.softmax(predictions), axis=-1)

print(
    f"Classification report:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

# Confusion matrix
cm = confusion_matrix(y_test, predicted, labels=class_names)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=class_names)
disp.plot()
plt.show()
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.99      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      0.98      0.98       982
#            5       0.98      0.99      0.98       892
#            6       0.98      0.99      0.98       958
#            7       0.98      0.99      0.98      1028
#            8       0.99      0.98      0.98       974
#            9       0.98      0.98      0.98      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
# Error analyses
from tqdm import tqdm

err = []
for i in range(len(y_test)):
  if y_test[i] != predicted[i]:
    err.append(i)

print('In total {:d} mistakes out of {:d} images'.format(len(err), len(y_test)))

for i in tqdm(range(len(err))):
  plt.imshow(X_test[err[i]], cmap=plt.cm.gray_r, interpolation="nearest")
  plt.title('Human thinks: {:},    NN recognizes: {:}'.format(y_test[err[i]], predicted[err[i]]))
  plt.savefig('./errors/{}.png'.format(err[i]), dpi=600)
# Out:
# In total 145 mistakes out of 10000 images
#  15%|████████████▍                                                                     | 22/145 [00:38<05:46,  2.82s/it]
